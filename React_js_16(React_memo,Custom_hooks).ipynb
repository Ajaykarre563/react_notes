# %% [markdown]
# # **What is React.memo?**
#
# React.memo is a higher-order component (HOC) in React that helps optimize performance by preventing unnecessary re-renders of a component.
#
# When to Use It?
# Use React.memo when:
# ✅ A component receives the same props frequently.
# ✅ The component doesn’t need to re-render unless its props change.

# %% [markdown]
# # **How it helps?**
#
# Without React.memo: The component re-renders every time the parent updates, even if the props don’t change.
#
# With React.memo: The component only re-renders when the props actually change, improving performance.

# %% [markdown]
# # **what is mean by  custom hook?**

# %% [markdown]
# **A custom hook in React is a reusable function that uses built-in hooks (useState, useEffect, etc.) to add functionality to multiple components without repeating code.**
#
# **Example**
#
# 👉 Instead of writing the same logic in multiple components, we create a custom hook and reuse it.

# %% [markdown]
# # **Create PageTitleOne Component**

# %% [markdown]
# ```
# import React, { useState } from "react";
# import usePageTitle from "./usePageTitle";
#
# const PageTitleOne = () => {
#   const [count, setCount] = useState(0);
#
#   usePageTitle(count);
#
#   return (
#     <div>
#       <h2>Page Title One</h2>
#       <button onClick={() => setCount(count + 1)}>Count - {count}</button>
#     </div>
#   );
# };
#
# export default PageTitleOne;
#
# ```

# %% [markdown]
# # **Create PageTitleTwo Component**

# %% [markdown]
# ```
# import React, { useState } from "react";
# import usePageTitle from "./usePageTitle";
#
# const PageTitleTwo = () => {
#   const [count, setCount] = useState(0);
#
#   usePageTitle(count);
#
#   return (
#     <div>
#       <h2>Page Title Two</h2>
#       <button onClick={() => setCount(count + 1)}>Count - {count}</button>
#     </div>
#   );
# };
#
# export default PageTitleTwo;
#
# ```

# %% [markdown]
# # **usePageTitle.js**

# %% [markdown]
# ```
# import { useEffect } from "react";
#
# function usePageTitle(count) {
#   useEffect(() => {
#     document.title = `Count - ${count}`;
#   }, [count]);
# }
#
# export default usePageTitle;
#
# ```

# %% [markdown]
# # **App.js**

# %% [markdown]
# ```
# import React from "react";
# import PageTitleOne from "./PageTitleOne";
# import PageTitleTwo from "./PageTitleTwo";
#
# const App = () => {
#   return (
#     <div>
#       <PageTitleOne />
#       <PageTitleTwo />
#     </div>
#   );
# };
#
# export default App;
#
# ```

# %% [markdown]
# ![ch.jpg](data:image/jpeg;base64,...)
