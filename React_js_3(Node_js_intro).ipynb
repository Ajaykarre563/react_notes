# %% [markdown]
# # **What is Node.js?**
#
# Node.js is a runtime environment that allows you to run JavaScript outside the browser, mainly on a server. It is built on Chrome's V8 engine and is used for backend development.
#
# Usage of Node.js in React.js
#
# In React, Node.js is mainly used for:
#
# ✅ Setting up the Development Environment – React apps use Node.js to install tools like Webpack, Babel, and libraries via npm (Node Package Manager).
#
# ✅ Creating a Backend API – You can build a backend using Node.js (with Express.js) to handle database interactions and serve data to the React frontend.
#
# ✅ Server-Side Rendering (SSR) – Improves SEO and performance by rendering React components on the server before sending them to the browser.
#
# **Simple Example**
#
# 1️⃣ Without Node.js
#
# You write JavaScript only in the browser (frontend).
#
# Cannot easily manage dependencies or run a backend.
#
# 2️⃣ With Node.js in React
#
# Install React with npx create-react-app my-app (uses Node.js).
#
# Use npm install to add packages like Axios, Redux, etc.
#
# Create a backend with Express.js to handle API requests.

# %% [markdown]
# # **What is an API? (Simple Explanation)**
#
# API (Application Programming Interface) is a bridge that allows two applications to communicate with each other.
#
# Think of it like:
#
# 👉 A waiter in a restaurant who takes your order (request) and brings back your food (response) from the kitchen (server).
#
# How APIs Work?
#
# 1️⃣ Frontend (React) → Sends a request to the API (e.g., "Give me user data").
#
# 2️⃣ Backend (Express.js) → Receives the request, processes it, and sends back a response.
#
# 3️⃣ Frontend → Receives the response and displays the data.

# %% [markdown]
# # **npm init**

# %% [markdown]
# **package.json is like a guidebook for a Node.js project—it lists the project details, dependencies, and scripts needed to run it.**

# %% [markdown]
# **If you did n't enter any name,version,main it will by default.**

# %% [markdown]
# ![Screenshot 2025-02-08 172117.png](data:image/png;base64,...)

# %% [markdown]
# #**npm install react-toastify --save**

# %% [markdown]
# **it is intall node_modules,package-lock.json**

# %% [markdown]
# ![Screenshot 2025-02-08 172256.png](data:image/png;base64,...)

# %% [markdown]
# # **node_modules is a folder where all the installed dependencies (packages) for a Node.js project are stored.**

# %% [markdown]
# # **The src folder is where you keep all your project's source code files.**

# %% [markdown]
# ![Screenshot 2025-02-08 174807.png](data:image/png;base64,...)

# %% [markdown]
# # **.gitignore is a file that tells Git which files and folders to ignore when tracking changes.**

# %% [markdown]
# # **`package-lock.json` ensures that the exact version of dependencies used in the project is installed every time. For example, it might lock "express" to version "4.17.1". for a couple of seconds**
#
# package-lock.json locks down the exact versions of your dependencies to ensure consistent installations across different environments.
# For example, if it specifies "express": "4.17.1", running npm install will always install version 4.17.1 of Express.

# %% [markdown]
# # **The scripts section in your package.json lets you create shortcut commands for tasks.**
#
# For example, if you add "start": "node app.js" in scripts, running npm start will execute node app.js.

# %% [markdown]
# # **Reasoned about ES6, ES5, and Babel in React**

# %% [markdown]
# **ES6 (ECMAScript 2015) is a modern version of JavaScript with new features (like arrow functions, classes, etc.), while ES5 is an older version with broader browser support.**
#
# In React development, you often write code using ES6 syntax, and Babel converts it into ES5 so that the code works on all browsers; for example, an ES6 arrow function:

# %% [markdown]
# ```
# const add = (a, b) => a + b;
#
# ```

# %% [markdown]
# **gets transpiled by Babel to an ES5 function**

# %% [markdown]
# ```
# var add = function(a, b) {
#   return a + b;
# };
#
# ```

# %% [markdown]
# # **What is Webpack?**
#
# Webpack is a module bundler for JavaScript applications. It takes all your JavaScript, CSS, images, and other assets, bundles them together, and optimizes them for better performance.
#
# **Usage of Webpack in React.js**
#
# In React.js, Webpack is used to:
#
# ✅ Bundle and Minify React components, CSS, and images into a single optimized file.
#
# ✅ Convert Modern JavaScript (ES6+) into browser-friendly code using Babel.
#
# ✅ Hot Module Replacement (HMR) for faster development by updating changes instantly without refreshing the page.
#
# ✅ Code Splitting to load only required parts of the app, improving performance.
#
# **Simple Example**
#
# Without Webpack: You have multiple files that the browser loads separately.
#
# With Webpack: All files are bundled into one optimized file, making the app faster and easier to manage.

# %% [markdown]
# ![Screenshot 2025-02-08 192602.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-08 192616.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-08 192630.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-08 192802.png](data:image/png;base64,...)
