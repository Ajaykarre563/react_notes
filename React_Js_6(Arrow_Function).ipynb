# %% [markdown]
# ![Screenshot 2025-02-09 084021.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-09 084056.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-09 084147.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-09 084056.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-09 084147.png](data:image/png;base64,...)

# %% [markdown]
# ![INNER.jpg](data:image/jpeg;base64,...)
