# %% [markdown]
# ## **What is JSX?**

# %% [markdown]
# **JSX (JavaScript XML) is a syntax extension for JavaScript that looks like HTML but works inside JavaScript code. It allows you to write HTML-like code in React, making it easier to create UI components.**

# %% [markdown]
# **JSX Rules (Simple Explanation)**
#
# Must return a single parent element

# %% [markdown]
# ```
# return (
#     <div>
#         <h1>Hello</h1>
#         <p>Welcome!</p>
#     </div>
# );
#
# ```

# %% [markdown]
# **JSX expressions must be wrapped inside {}**

# %% [markdown]
# ```
# const name = "Ajay";
# return <h1>Hello, {name}!</h1>; // ✅ Correct
#
# ```

# %% [markdown]
# **Self-closing tags for empty elements**

# %% [markdown]
# ```
# <img src="image.jpg" alt="Example" />
#
# ```

# %% [markdown]
# Comments in JSX use {/* ... */}

# %% [markdown]
# ```
# return (
#     <div>
#         {/* This is a JSX comment */}
#         <h1>Hello</h1>
#     </div>
# );
#
# ```

# %% [markdown]
# **Why Use JSX?**
#
# ✅ Easier to read and write than React.createElement()
#
# ✅ Looks like HTML, but it’s JavaScript inside React
#
# ✅ Improves developer productivity 🚀

# %% [markdown]
# **Why is div tag Used?**
#
# JSX does not allow returning multiple root elements directly. To fix this, we wrap them inside a <div> (or another parent element).

# %% [markdown]
# # **What is section tag in JSX?**
#
# **section tag is an HTML semantic tag used to group related content in a web page. In JSX, it works just like a <div>, but it has meaning—it indicates that the enclosed content belongs to a specific section of the page.**

# %% [markdown]
# When to Use div vs. section?
#
# ✅ Use section tag when content is related (like an "About Us" or "Services" section).
#
# ✅ Use div tag for styling, layout, or when there’s no semantic meaning needed.

# %% [markdown]
# # **How to Use class in JSX?**
#
# **In JSX, you cannot use class (because class is a reserved keyword in JavaScript). Instead, you must use className to apply CSS classes.**

# %% [markdown]
# ```
# import React from 'react';
# import './styles.css'; // Import CSS file
#
# function App() {
#     return (
#         <section className="container">
#             <h1 className="heading">Welcome to My Website</h1>
#             <p className="description">This is a section with a class.</p>
#         </section>
#     );
# }
#
# export default App;
#
# ```

# %% [markdown]
# # **What Are Attributes in JSX?**
#
# **In JSX, attributes are properties or values assigned to HTML-like elements to customize or define their behavior. These attributes are similar to HTML attributes, but there are some differences in naming conventions in JSX.**

# %% [markdown]
# **Common JSX Attributes**
#
# className (instead of class) for CSS classes.
#
# htmlFor (instead of for) for labeling form elements.
#
# style for inline CSS styles.
#
# onClick for event handling.
#
# And many others, depending on the type of element.

# %% [markdown]
# ```
# import React from 'react';
#
# function App() {
#     const containerStyle = {
#         padding: '20px',
#         backgroundColor: 'lightblue'
#     };
#
#     const handleClick = () => {
#         alert("Button clicked!");
#     };
#
#     return (
#         <div className="container" style={containerStyle}>
#             <h1>Welcome to My Website</h1>
#             <p>This is a paragraph with some inline styles and events.</p>
#             <button onClick={handleClick}>Click Me</button>
#         </div>
#     );
# }
#
# export default App;
#
# ```

# %% [markdown]
# **Explanation:**
#
# **className:**
#
# Used to assign a CSS class to the element. JSX uses className instead of class (to avoid conflict with JavaScript's class keyword).
# Example: div className="container"
#
# **style:**
#
# Used to apply inline styles in JSX. The value of style is an object with key-value pairs representing CSS properties.

# %% [markdown]
# ![Screenshot 2025-02-09 065810.png](data:image/png;base64,...)

# %% [markdown]
# # **How we use  Use JavaScript in JSX?**

# %% [markdown]
# **In JSX (JavaScript XML), we use JavaScript by embedding expressions inside curly braces {}. JSX is an extension of JavaScript used in React, allowing us to write UI components in a syntax similar to HTML while leveraging JavaScript capabilities.**

# %% [markdown]
# # **Ways to Use JavaScript in JSX**
#
# **Embedding Expressions**
#
# You can use JavaScript expressions inside {} in JSX.

# %% [markdown]
# ```
# const name = "John";
# const element = <h1>Hello, {name}!</h1>;
#
# ```

# %% [markdown]
# # **Are App.js and App.jsx the same?**
#
# Yes, App.js and App.jsx can work the same way, but there are some differences in naming conventions and best practices.

# %% [markdown]
# ![Screenshot 2025-02-09 071333.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-09 071419.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-09 071507.png](data:image/png;base64,...)
